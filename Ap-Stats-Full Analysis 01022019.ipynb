# %%
import pyspark
import pandas as pd
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
data = spark.read.parquet('/Users/jingcheng/Code/1_10_00')

# %%
data.head(3)[1].asDict().keys()
# Out:
# ['config_time',
#  'radios',
#  'load_total',
#  'site_id',
#  'slab_num_objs',
#  'firmware_version',
#  'id',
#  'lldp_pwr',
#  'memory_used_kb',
#  'inactive_wired_vlans',
#  'temperature_ambient',
#  'uptime',
#  'fs_available_kb',
#  'lldp_nd',
#  'total_client_count',
#  'cloud_pmtu',
#  'temperature_attitude',
#  'when',
#  'dhcpclients',
#  'pwr_src',
#  'dnsServers',
#  'terminator_timestamp',
#  'slab_active_objs',
#  'cloud_last_rtt',
#  'pwr_budget',
#  'cpu_user',
#  'terminator_remote_addr',
#  'slab_obj_size',
#  'temperature_cpu',
#  'fs_total_kb',
#  'svis',
#  'pwr_available',
#  'pwr_needed',
#  'orientation_accel_y',
#  'orientation_accel_x',
#  'orientation_accel_z',
#  'cpu_total_time',
#  'active_client_count',
#  'interval',
#  'org_id',
#  'memory_total_kb',
#  'cpu_system',
#  'orientation_magne_z',
#  'orientation_magne_y',
#  'orientation_magne_x',
#  'wlans',
#  'l2tptunnels',
#  'model',
#  'IPv4Routers',
#  'switchports']

# %%
#data.describe('uptime').show()
#data.select('active_client_count').distinct().show()
#data.select('wlans').show()

# %%
datacopy = spark.read.parquet('/Users/jingcheng/Code/1_10_00')

# %%
length = data.count()

# %%
specialkey = []
specialtype = []
for key in data.head(1)[0].asDict().keys():
    #print data.head(1)[0].asDict()[key]
    if not (isinstance(data.head(1)[0].asDict()[key], int) or \
            isinstance(data.head(1)[0].asDict()[key], float) or \
            isinstance(data.head(1)[0].asDict()[key], unicode)):
        specialkey.append(key)
        specialtype.append([key, type(data.head(1)[0].asDict()[key])])

# %%
specialtype
# Out:
# [['radios', list],
#  ['lldp_pwr', pyspark.sql.types.Row],
#  ['inactive_wired_vlans', list],
#  ['temperature_ambient', NoneType],
#  ['lldp_nd', pyspark.sql.types.Row],
#  ['total_client_count', NoneType],
#  ['dhcpclients', list],
#  ['dnsServers', list],
#  ['svis', list],
#  ['active_client_count', NoneType],
#  ['orientation_magne_y', NoneType],
#  ['wlans', list],
#  ['l2tptunnels', list],
#  ['IPv4Routers', list],
#  ['switchports', list]]

# %%
for key in data.head(1)[0].asDict().keys():
    #print data.head(1)[0].asDict()[key]
    if not (isinstance(data.head(1)[0].asDict()[key], int) or \
            isinstance(data.head(1)[0].asDict()[key], float) or \
            isinstance(data.head(1)[0].asDict()[key], unicode)):
        specialtype.append([key, type(data.head(1)[0].asDict()[key])])

# %%
# take each column of data
result = []
for col in data.head(1)[0].asDict().keys():
     result.append([data.head(length)[i].asDict()[col] for i in range(3)])
result
# Out:
# [[1545347137, 1545347137, 1545349605],
# ...

# %%
result = [data.head(length)[i].asDict()['temperature_ambient'] for i in range(length)]
result
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
result = [data.head(length)[i].asDict()['total_client_count'] for i in range(length)]
result
# Out:
# [None,
#  10,
#  None,
#  4,
#  None,
#  1,
#  1,
#  None,
#  2,
#  None,
#  1,
#  30,
#  None,
#  None,
#  None,
#  1,
#  3,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  1,
#  3,
#  None,
#  1,
#  None,
#  12,
#  None,
#  None,
#  14,
#  None,
#  None,
#  None,
#  1,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  5,
#  None,
#  None,
#  30,
#  None,
#  None,
#  None,
#  None,
#  5,
#  None,
#  None,
#  None,
#  None,
#  1,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  4,
#  None,
#  None,
#  None,
#  1,
#  12,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  1,
#  None,
#  None,
#  None,
#  2,
#  None,
#  None,
#  None,
#  7,
#  2,
#  1,
#  None,
#  2,
#  None,
#  30,
#  1,
#  None,
#  None,
#  None,
#  None,
#  2,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  1,
#  3,
#  None,
#  None,
#  None,
#  None,
#  5,
#  None,
#  1,
#  3,
#  None,
#  6,
# ...

# %%
result = [data.head(length)[i].asDict()['active_client_count'] for i in range(length)]
result
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
result = [data.head(length)[i].asDict()['orientation_magne_y'] for i in range(length)]
result
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
result = [data.head(length)[i].asDict()['inactive_wired_vlans'] for i in range(length)]
result
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [1],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...

# %%
result = [data.head(length)[i].asDict()['radios'] for i in range(length)]
result
# Out:
# [[Row(dev=u'r0', band=u'24', channel=6, secondary_channel=None, bandwidth=20, noise_floor=-92, tx_power=None, max_tx_power=14, per_antenna_rssi=[-64, -63, -63, -65], utilization_all=0.12064298242330551, utilization_tx=0.023398738354444504, utilization_rx_in_bss=0.0001363571936963126, utilization_rx_other_bss=0.0001363571936963126, utilization_unknown_wifi=0.008604078553617, utilization_non_wifi=0.0388357974588871, dfs_radar_detected=None, dfs_cac_state=None, counter=Row(tx_bytes=None, tx_pkts=None, tx_mgmt=None, tx_errors=None, rx_bytes=None, rx_pkts=None, rx_mgmt=978, rx_errors=None, tx_failed_arp=None, tx_drop_arp=None, tx_psblk_fifo=None, tx_toss=584, tx_toss_arp=None, tx_toss_bcmc=None, tx_toss_unicast=None, tx_bcmc2unicast=None, tx_bcmc2unicast_client=None, tx_bcn_intr=601, tx_phy_err=None, tx_failed=None, tx_retries=None, tx_retried=None, rx_dups=None, rx_retried=None, tx_bcmc2unicast_bytes=None, tx_bcmc2unicast_client_bytes=None, re_init=None, re_init_throttle=None, tx_mgmt_dr
# ...

# %%
'''[['radios', list],
 ['lldp_pwr', pyspark.sql.types.Row], # struct type, use .* to flatten
 ['inactive_wired_vlans', list],      # all []
 ['temperature_ambient', NoneType],   # all None           TBD
 ['lldp_nd', pyspark.sql.types.Row],  # struct type, use .* to flatten
 ['total_client_count', NoneType],    # None and int       None -> 0
 ['dhcpclients', list],               # consider empty list [], 1 by 1 append to pandas
 ['dnsServers', list],                # one value: a list including various server ip
 ['svis', list],                      # 1 by 1 append to pandas
 ['active_client_count', NoneType],   # most None and int  None -> 0
 ['orientation_magne_y', NoneType],   # all None
 ['wlans', list],
 ['l2tptunnels', list],
 ['IPv4Routers', list],
 ['switchports', list]]               # has two or three records, need to consider different cases
 '''

# %% [markdown]
# # Flatten Data

# %%
flatdata = pd.DataFrame()

for key in data.head(1)[0].asDict().keys():
    #print data.head(1)[0].asDict()[key]
    if (isinstance(data.head(1)[0].asDict()[key], int) or \
        isinstance(data.head(1)[0].asDict()[key], float) or \
        isinstance(data.head(1)[0].asDict()[key], unicode)):
        flatdata[]

# %%
for key in specialtype:
    print '---' + key[0]
    print data.head(1)[0].asDict()[key[0]]
    print '\n'
# Out:
# ---radios
# ...

# %% [markdown]
# ##        non-nested data convert to pandas

# %%
datacopy = datacopy.drop(*specialkey)

# %%
flatdata = datacopy.toPandas()

# %%
flatdata
# Out:
#                     id                               site_id  \
# 0    5c-5b-35-0e-be-84  7e21754c-510c-11e5-997e-1258369c38a9
# 1    5c-5b-35-0e-00-a0  ce48d2e4-e668-11e5-a6cd-0242ac110003
# 2    5c-5b-35-0e-55-a5  f4b1eb51-32f5-4926-8383-be82b2e1a4c8
# 3    5c-5b-35-0e-b1-fe  ee915a44-b963-11e5-b14c-1258369c38a9
# 4    5c-5b-35-0e-61-68  cd5a3b5a-6b21-11e6-a17e-0242ac110005
# 5    5c-5b-35-0e-60-b4  29d2648e-e66b-11e5-a6cd-0242ac110003
# 6    5c-5b-35-0e-60-b4  29d2648e-e66b-11e5-a6cd-0242ac110003
# 7    5c-5b-35-1e-13-b5  67970e46-4e12-11e6-9188-0242ac110007
# 8    54-45-53-54-48-8f  de1424b8-843f-4fa8-8587-bb2a3f9e545d
# 9    5c-5b-35-0e-53-07  0e7f3fd2-bce0-4da6-965a-aec22d876837
# 10   5c-5b-35-0e-57-a8  c4a51a2c-ad73-11e6-b0cc-0242ac110004
# 11   54-45-53-54-4e-1f  de1424b8-843f-4fa8-8587-bb2a3f9e545d
# 12   5c-5b-35-0f-32-1c  20325077-2d75-4fa9-b801-7fc2686afb69
# 13   5c-5b-35-0e-61-9a  0a6ceeb3-4b49-4df9-a235-14ac9c85b884
# ...

# %% [markdown]
# ## Convert pyspark.sql.types.Row to Pandas

# %%
lldp_nd = data.select('lldp_nd.*').toPandas()
lldp_nd
# Out:
#                   port_desc                   sys_name  \
# 0                      None                       None
# 1                      None                       None
# 2                      None                       None
# 3                      None                       None
# 4              ap-6168-mesh                  amber-usw
# 5                      None                       None
# 6                      None                       None
# 7                      None                       None
# 8                      None                       None
# 9                      None                       None
# 10                     None                       None
# 11                     None                       None
# 12                     None                       None
# 13                     None                       None
# 14                     None                       None
# 15                  Port 11              Wired Network
# ...

# %%
lldp_pwr = data.select('lldp_pwr.*').toPandas()
lldp_pwr
# Out:
#      req_cnt xtnd_sup  pse_avail   pd_req  pd_needs
# 0        NaN     None        NaN      NaN       NaN
# 1        NaN     None        NaN      NaN       NaN
# 2        NaN     None        NaN      NaN       NaN
# 3        NaN     None        NaN      NaN       NaN
# 4        NaN     None        NaN      NaN       NaN
# 5        NaN     None        NaN      NaN       NaN
# 6        NaN     None        NaN      NaN       NaN
# 7        NaN     None        NaN      NaN       NaN
# 8        NaN     None        NaN      NaN       NaN
# 9        NaN     None        NaN      NaN       NaN
# 10       NaN     None        NaN      NaN       NaN
# 11       NaN     None        NaN      NaN       NaN
# 12       NaN     None        NaN      NaN       NaN
# 13       NaN     None        NaN      NaN       NaN
# 14       NaN     None        NaN      NaN       NaN
# 15       NaN     None        NaN      NaN       NaN
# 16       NaN     None        NaN      NaN       NaN
# ...

# %%
svis = pd.DataFrame()

for i in range(length):
    svis = svis.append(pd.DataFrame(data.head(length)[i].asDict()['svis'][0].asDict()))

# %%
svis
# Out:
#       dev                ips  vlan
# 0   vlan1   192.168.1.131/24     1
# 0   vlan1  192.168.86.127/24     1
# 0   vlan1   192.168.0.101/24     1
# 0   vlan1     192.168.0.8/23     1
# 0   vlan1    192.168.1.39/24     1
# 0   vlan1    192.168.1.53/24     1
# 0   vlan1    192.168.1.53/24     1
# 0   vlan1      10.2.15.44/18     1
# 0   vlan1      10.2.15.18/18     1
# 0   vlan1     172.29.9.28/24     1
# 0   vlan1     172.29.9.21/24     1
# 0   vlan1         10.0.0.1/8     1
# 0   vlan1     10.7.118.50/24     1
# 0   vlan1    192.168.15.7/24     1
# 0   vlan1      10.2.15.44/18     1
# 0   vlan1      10.0.0.167/24     1
# 0   vlan1    192.168.0.31/23     1
# 0   vlan1   192.168.0.101/24     1
# 0   vlan1  172.29.101.151/24     1
# 0   vlan1  172.29.101.111/24     1
# 0   vlan1      10.2.10.74/18     1
# 0   vlan1    192.168.15.7/24     1
# 0   vlan1      172.16.1.9/24     1
# 0   vlan1      10.0.0.167/24     1
# 0   vlan1    192.168.0.31/23     1
# 0   vlan1      10.2.10.65/18     1
# ...

# %%
data.select('dhcpclients').take(15)  # when dhcpclients has emplty list [], treat it as 0??
# Out:
# [Row(dhcpclients=[Row(dev=u'vlan1', ip=u'192.168.1.131/24', gateway=u'192.168.1.1')]),
#  Row(dhcpclients=[Row(dev=u'vlan1', ip=u'192.168.86.127/24', gateway=u'192.168.86.1')]),
#  Row(dhcpclients=[Row(dev=u'vlan1', ip=u'192.168.0.101/24', gateway=u'192.168.0.1')]),
#  Row(dhcpclients=[Row(dev=u'vlan1', ip=u'192.168.0.8/23', gateway=u'192.168.0.1')]),
#  Row(dhcpclients=[Row(dev=u'vlan1', ip=u'192.168.1.39/24', gateway=u'192.168.1.1')]),
#  Row(dhcpclients=[Row(dev=u'vlan1', ip=u'192.168.1.53/24', gateway=u'192.168.1.1')]),
#  Row(dhcpclients=[Row(dev=u'vlan1', ip=u'192.168.1.53/24', gateway=u'192.168.1.1')]),
#  Row(dhcpclients=[Row(dev=u'vlan1', ip=u'10.2.15.44/18', gateway=u'10.2.1.1')]),
#  Row(dhcpclients=[Row(dev=u'vlan1', ip=u'10.2.15.18/18', gateway=u'10.2.1.1')]),
#  Row(dhcpclients=[Row(dev=u'vlan1', ip=u'172.29.9.28/24', gateway=u'172.29.9.1')]),
#  Row(dhcpclients=[Row(dev=u'vlan1', ip=u'172.29.9.21/24', gateway=u'172.29.9.1')]),
#  Row(dhcpclients=[]),
# ...

# %%
dhcpclients = pd.DataFrame()

for i in range(length):
    if data.head(length)[i].asDict()['dhcpclients'] == []:
        dhcpclients = dhcpclients.append(pd.DataFrame({'dev': u'0', 'gateway': u'0', 'ip': u'0'}, index = [i]))
    else:
        dhcpclients = dhcpclients.append(pd.DataFrame(data.head(length)[i].asDict()['dhcpclients'][0].asDict(), index=[i]))

# %%
dhcpclients
# Out:
#        dev       gateway                 ip
# 0    vlan1   192.168.1.1   192.168.1.131/24
# 1    vlan1  192.168.86.1  192.168.86.127/24
# 2    vlan1   192.168.0.1   192.168.0.101/24
# 3    vlan1   192.168.0.1     192.168.0.8/23
# 4    vlan1   192.168.1.1    192.168.1.39/24
# 5    vlan1   192.168.1.1    192.168.1.53/24
# 6    vlan1   192.168.1.1    192.168.1.53/24
# 7    vlan1      10.2.1.1      10.2.15.44/18
# 8    vlan1      10.2.1.1      10.2.15.18/18
# 9    vlan1    172.29.9.1     172.29.9.28/24
# 10   vlan1    172.29.9.1     172.29.9.21/24
# 11       0             0                  0
# 12   vlan1    10.7.118.1     10.7.118.50/24
# 13   vlan1  192.168.15.1    192.168.15.7/24
# 14   vlan1      10.2.1.1      10.2.15.44/18
# 15   vlan1      10.0.0.1      10.0.0.167/24
# 16   vlan1   192.168.0.1    192.168.0.31/23
# 17   vlan1   192.168.0.1   192.168.0.101/24
# 18   vlan1  172.29.101.1  172.29.101.151/24
# 19   vlan1  172.29.101.1  172.29.101.111/24
# ...

# %%
### Start from here ###

# %%
data.select('dnsServers').take(5)
# Out:
# [Row(dnsServers=[u'192.168.1.189', u'75.75.75.75', u'75.75.76.76']),
#  Row(dnsServers=[u'192.168.86.1']),
#  Row(dnsServers=[u'192.168.0.1', u'0.0.0.0']),
#  Row(dnsServers=[u'75.75.75.75', u'75.75.76.76']),
#  Row(dnsServers=[u'8.8.4.4', u'8.8.8.8'])]

# %%
dnsServers = pd.DataFrame()

for i in range(length):
    dnsServers = dnsServers.append(pd.DataFrame({'dnsServers': [data.head(length)[i].asDict()['dnsServers']]}))

# %%
dnsServers
# Out:
#                                            dnsServers
# 0           [192.168.1.189, 75.75.75.75, 75.75.76.76]
# 0                                      [192.168.86.1]
# 0                              [192.168.0.1, 0.0.0.0]
# 0                          [75.75.75.75, 75.75.76.76]
# 0                                  [8.8.4.4, 8.8.8.8]
# 0                                       [192.168.1.1]
# 0                                       [192.168.1.1]
# 0                                  [8.8.8.8, 8.8.4.4]
# 0                                  [8.8.8.8, 8.8.4.4]
# 0                                      [172.29.101.7]
# 0                                      [172.29.101.7]
# 0                                                  []
# 0                                  [8.8.8.8, 8.8.4.4]
# 0                          [75.75.75.75, 75.75.76.76]
# 0                                  [8.8.8.8, 8.8.4.4]
# 0                                  [8.8.8.8, 8.8.4.4]
# ...

# %%
data.select('wlans').take(4)  # why multiple r1 for row 4?
# Out:
# [Row(wlans=[Row(id=u'2b7e3871-f198-4b2c-ac7a-e6f27e210e72', radio_index=None, bssid=u'5c-5b-35-03-ef-12', dev=None, ssid=u'calme l2tp', num_clients=None, tx_mcast_pkts=16585, tx_mcast_bytes=886930, radius_auth=[], radius_acct=[], radio=u'r0'), Row(id=u'2b7e3871-f198-4b2c-ac7a-e6f27e210e72', radio_index=1, bssid=u'5c-5b-35-03-ef-23', dev=None, ssid=u'calme l2tp', num_clients=None, tx_mcast_pkts=16585, tx_mcast_bytes=886930, radius_auth=[], radius_acct=[], radio=u'r1')]),
#  Row(wlans=[Row(id=u'e18fc344-e668-11e5-a6cd-0242ac110003', radio_index=None, bssid=u'5c-5b-35-00-07-81', dev=None, ssid=u'CupOfCoffee', num_clients=5, tx_mcast_pkts=6144067, tx_mcast_bytes=1947376532, radius_auth=[], radius_acct=[], radio=u'r0'), Row(id=u'e18fc344-e668-11e5-a6cd-0242ac110003', radio_index=1, bssid=u'5c-5b-35-00-07-91', dev=None, ssid=u'CupOfCoffee', num_clients=5, tx_mcast_pkts=6144068, tx_mcast_bytes=1947376610, radius_auth=[], radius_acct=[], radio=u'r1')]),
# ...

# %%
wlans = []

# %%
wlans.append(pd.DataFrame({'d':13}, index = [0]))
wlans.append(pd.DataFrame({'c':10}, index = [1]))

# %%
wlans
# Out:
# [    d
#  0  13,     c
#  1  10]

# %%
switchports0 = pd.DataFrame()
switchports1 = pd.DataFrame()
switchports2 = pd.DataFrame()

for i in range(length):
    #print j
    for j, name in enumerate(data.head(length)[i].asDict()['switchports']):
        max = j
    #print 'max',max
    if max == 0:
        switchports0 = switchports0.append(pd.DataFrame(data.head(length)[i].asDict()['switchports'][0].asDict(), index = [i]))
    elif max == 1:
        switchports0 = switchports0.append(pd.DataFrame(data.head(length)[i].asDict()['switchports'][0].asDict(), index = [i]))
        switchports1 = switchports1.append(pd.DataFrame(data.head(length)[i].asDict()['switchports'][1].asDict(), index = [i]))
    elif max == 2:
        switchports0 = switchports0.append(pd.DataFrame(data.head(length)[i].asDict()['switchports'][0].asDict(), index = [i]))
        switchports1 = switchports1.append(pd.DataFrame(data.head(length)[i].asDict()['switchports'][1].asDict(), index = [i]))
        switchports2 = switchports2.append(pd.DataFrame(data.head(length)[i].asDict()['switchports'][2].asDict(), index = [i]))
    else: 
        print 'none'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-421-00e0aa295a88> in <module>()
# ----> 1 len(data.head(length)[0].asDict()['wlans'])
#
# TypeError: 'int' object is not callable

# %%
'''l2tptunnels', list],
 ['IPv4Routers', list],
 ['switchports', list]]
'''
data.select('l2tptunnels').take(10)  # might not be useful
# Out:
# [Row(l2tptunnels=[]),
#  Row(l2tptunnels=[]),
#  Row(l2tptunnels=[]),
#  Row(l2tptunnels=[]),
#  Row(l2tptunnels=[]),
#  Row(l2tptunnels=[]),
#  Row(l2tptunnels=[]),
#  Row(l2tptunnels=[]),
#  Row(l2tptunnels=[]),
#  Row(l2tptunnels=[])]

# %%
data.select('IPv4Routers').take(10)  # might not be useful
# Out:
# [Row(IPv4Routers=[Row(dest=u'0.0.0.0/0', gateway=u'192.168.1.1')]),
#  Row(IPv4Routers=[Row(dest=u'0.0.0.0/0', gateway=u'192.168.86.1')]),
#  Row(IPv4Routers=[Row(dest=u'0.0.0.0/0', gateway=u'192.168.0.1')]),
#  Row(IPv4Routers=[Row(dest=u'0.0.0.0/0', gateway=u'192.168.0.1')]),
#  Row(IPv4Routers=[Row(dest=u'0.0.0.0/0', gateway=u'192.168.1.1')]),
#  Row(IPv4Routers=[Row(dest=u'0.0.0.0/0', gateway=u'192.168.1.1')]),
#  Row(IPv4Routers=[Row(dest=u'0.0.0.0/0', gateway=u'192.168.1.1')]),
#  Row(IPv4Routers=[Row(dest=u'0.0.0.0/0', gateway=u'10.2.1.1')]),
#  Row(IPv4Routers=[Row(dest=u'0.0.0.0/0', gateway=u'10.2.1.1')]),
#  Row(IPv4Routers=[Row(dest=u'0.0.0.0/0', gateway=u'172.29.9.1')])]

# %%
switchports0 = pd.DataFrame()
switchports1 = pd.DataFrame()
switchports2 = pd.DataFrame()

for i in range(length):
    #print j
    for j, name in enumerate(data.head(length)[i].asDict()['switchports']):
        max = j
    #print 'max',max
    if max == 0:
        switchports0 = switchports0.append(pd.DataFrame(data.head(length)[i].asDict()['switchports'][0].asDict(), index = [i]))
    elif max == 1:
        switchports0 = switchports0.append(pd.DataFrame(data.head(length)[i].asDict()['switchports'][0].asDict(), index = [i]))
        switchports1 = switchports1.append(pd.DataFrame(data.head(length)[i].asDict()['switchports'][1].asDict(), index = [i]))
    elif max == 2:
        switchports0 = switchports0.append(pd.DataFrame(data.head(length)[i].asDict()['switchports'][0].asDict(), index = [i]))
        switchports1 = switchports1.append(pd.DataFrame(data.head(length)[i].asDict()['switchports'][1].asDict(), index = [i]))
        switchports2 = switchports2.append(pd.DataFrame(data.head(length)[i].asDict()['switchports'][2].asDict(), index = [i]))
    else: 
        switchports0 = switchports0.append({'full_duplex': None,\
                                             'link': None,\
                                             'mbps': None,\
                                             'name': None,\
                                             'rx_bytes': None,\
                                             'rx_errors': None,\
                                             'rx_pkts': None,\
                                             'tx_bytes': None,\
                                             'tx_pkts': None}, ignore_index = True)
        switchports1 = switchports1.append({'full_duplex': None,\
                                             'link': None,\
                                             'mbps': None,\
                                             'name': None,\
                                             'rx_bytes': None,\
                                             'rx_errors': None,\
                                             'rx_pkts': None,\
                                             'tx_bytes': None,\
                                             'tx_pkts': None}, ignore_index = True)
        switchports2 = switchports2.append({'full_duplex': None,\
                                             'link': None,\
                                             'mbps': None,\
                                             'name': None,\
                                             'rx_bytes': None,\
                                             'rx_errors': None,\
                                             'rx_pkts': None,\
                                             'tx_bytes': None,\
                                             'tx_pkts': None}, ignore_index = True)

# %%
#data.head(length)[i].asDict()['switchports'][2].asDict()

# %%
switchports01 = pd.merge(switchports0, switchports1, left_index = True, right_index = True, how = 'left', suffixes=('_0', '_1'))

# %%
switchports = pd.merge(switchports01, switchports2, left_index = True, right_index = True, how = 'left')

# %%
switchports
# Out:
#     full_duplex_0 link_0 mbps_0 name_0 rx_bytes_0 rx_errors_0 rx_pkts_0  \
# 0            True   True   1000   eth0      15107        None        50
# 1            True   True   1000   eth0     510752        None      1132
# 2            True   True    100   eth0       1819        None        13
# 3            True   True   1000   eth0      24041        None       196
# 4            True   True   1000   eth0       6712        None        65
# 5            True   True    100   eth0   71524022        None     48510
# 6            True   True    100   eth0   13399529        None     10261
# 7            True   True    100   eth0     234637        None      1695
# 8            True   True   1000   eth0  344580693        None    238146
# 9            True   True   1000   eth0       3460        None        44
# 10           True   True   1000   eth0       5383        None        50
# 11           True   True   1000   eth0     994311        None      7403
# ...

# %% [markdown]
# ### Radios ###

# %%
data.select('radios').take(1)  # 29 attributes
# Out:
# [Row(radios=[Row(dev=u'r0', band=u'24', channel=6, secondary_channel=None, bandwidth=20, noise_floor=-92, tx_power=None, max_tx_power=14, per_antenna_rssi=[-64, -63, -63, -65], utilization_all=0.12064298242330551, utilization_tx=0.023398738354444504, utilization_rx_in_bss=0.0001363571936963126, utilization_rx_other_bss=0.0001363571936963126, utilization_unknown_wifi=0.008604078553617, utilization_non_wifi=0.0388357974588871, dfs_radar_detected=None, dfs_cac_state=None, counter=Row(tx_bytes=None, tx_pkts=None, tx_mgmt=None, tx_errors=None, rx_bytes=None, rx_pkts=None, rx_mgmt=978, rx_errors=None, tx_failed_arp=None, tx_drop_arp=None, tx_psblk_fifo=None, tx_toss=584, tx_toss_arp=None, tx_toss_bcmc=None, tx_toss_unicast=None, tx_bcmc2unicast=None, tx_bcmc2unicast_client=None, tx_bcn_intr=601, tx_phy_err=None, tx_failed=None, tx_retries=None, tx_retried=None, rx_dups=None, rx_retried=None, tx_bcmc2unicast_bytes=None, tx_bcmc2unicast_client_bytes=None, re_init=None, re_init_throttle=None,
# ...

# %%
#length = 10

ampdu_rx0 = pd.DataFrame()
ampdu_rx1 = pd.DataFrame()
ampdu_rx2 = pd.DataFrame()

for i in range(length):
    #print i
    if data.head(length)[i].asDict()['radios'] == []:
        ampdu_rx0 = ampdu_rx0.append({'holes': None,\
                                     'rx_add_ba_req': None,\
                                     'rx_bar': None,\
                                     'rx_del_ba': None,\
                                     'rx_unexpect': None,\
                                     'stuck': None,\
                                     'tx_add_ba_resp': None,\
                                     'tx_ba': None,\
                                     'tx_del_ba': None},ignore_index=True)
        
        ampdu_rx1 = ampdu_rx1.append({'holes': None,\
                                     'rx_add_ba_req': None,\
                                     'rx_bar': None,\
                                     'rx_del_ba': None,\
                                     'rx_unexpect': None,\
                                     'stuck': None,\
                                     'tx_add_ba_resp': None,\
                                     'tx_ba': None,\
                                     'tx_del_ba': None},ignore_index=True)
        
        ampdu_rx2 = ampdu_rx2.append({'holes': None,\
                                     'rx_add_ba_req': None,\
                                     'rx_bar': None,\
                                     'rx_del_ba': None,\
                                     'rx_unexpect': None,\
                                     'stuck': None,\
                                     'tx_add_ba_resp': None,\
                                     'tx_ba': None,\
                                     'tx_del_ba': None},ignore_index=True)
    else:
        for j, name in enumerate(data.head(length)[i].asDict()['radios']):
            max = j
        if max == 0:
            #print 'max=0'
            ampdu_rx0 = ampdu_rx0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['ampdu_rx'].asDict(), index = [i]))   
        elif max == 1:
            #print 'max=1'
            ampdu_rx0 = ampdu_rx0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['ampdu_rx'].asDict(), index = [i]))   
            ampdu_rx1 = ampdu_rx1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['ampdu_rx'].asDict(), index = [i]))
        elif max == 2:
            #print 'max=2'
            ampdu_rx0 = ampdu_rx0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['ampdu_rx'].asDict(), index = [i]))   
            ampdu_rx1 = ampdu_rx1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['ampdu_rx'].asDict(), index = [i]))
            ampdu_rx2 = ampdu_rx2.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][2].asDict()['ampdu_rx'].asDict(), index = [i]))
        else: 
            ampdu_rx0 = ampdu_rx0.append({'holes': None,\
                                     'rx_add_ba_req': None,\
                                     'rx_bar': None,\
                                     'rx_del_ba': None,\
                                     'rx_unexpect': None,\
                                     'stuck': None,\
                                     'tx_add_ba_resp': None,\
                                     'tx_ba': None,\
                                     'tx_del_ba': None},ignore_index=True)
        
            ampdu_rx1 = ampdu_rx1.append({'holes': None,\
                                     'rx_add_ba_req': None,\
                                     'rx_bar': None,\
                                     'rx_del_ba': None,\
                                     'rx_unexpect': None,\
                                     'stuck': None,\
                                     'tx_add_ba_resp': None,\
                                     'tx_ba': None,\
                                     'tx_del_ba': None},ignore_index=True)
        
            ampdu_rx2 = ampdu_rx2.append({'holes': None,\
                                     'rx_add_ba_req': None,\
                                     'rx_bar': None,\
                                     'rx_del_ba': None,\
                                     'rx_unexpect': None,\
                                     'stuck': None,\
                                     'tx_add_ba_resp': None,\
                                     'tx_ba': None,\
                                     'tx_del_ba': None},ignore_index=True)
# Out:
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none

# %%
data.head(1)[0].asDict()['radios']
# Out:
# [Row(dev=u'r0', band=u'24', channel=6, secondary_channel=None, bandwidth=20, noise_floor=-92, tx_power=None, max_tx_power=14, per_antenna_rssi=[-64, -63, -63, -65], utilization_all=0.12064298242330551, utilization_tx=0.023398738354444504, utilization_rx_in_bss=0.0001363571936963126, utilization_rx_other_bss=0.0001363571936963126, utilization_unknown_wifi=0.008604078553617, utilization_non_wifi=0.0388357974588871, dfs_radar_detected=None, dfs_cac_state=None, counter=Row(tx_bytes=None, tx_pkts=None, tx_mgmt=None, tx_errors=None, rx_bytes=None, rx_pkts=None, rx_mgmt=978, rx_errors=None, tx_failed_arp=None, tx_drop_arp=None, tx_psblk_fifo=None, tx_toss=584, tx_toss_arp=None, tx_toss_bcmc=None, tx_toss_unicast=None, tx_bcmc2unicast=None, tx_bcmc2unicast_client=None, tx_bcn_intr=601, tx_phy_err=None, tx_failed=None, tx_retries=None, tx_retried=None, rx_dups=None, rx_retried=None, tx_bcmc2unicast_bytes=None, tx_bcmc2unicast_client_bytes=None, re_init=None, re_init_throttle=None, tx_mgmt_dro
# ...

# %%
#length = 10

ampdu_tx0 = pd.DataFrame()
ampdu_tx1 = pd.DataFrame()
ampdu_tx2 = pd.DataFrame()

for i in range(length):
    #print i
    if data.head(length)[i].asDict()['radios'] == []:
        ampdu_tx0 = ampdu_tx0.append({'block_data_fifo': None,
                                     'drop': None,
                                     'drop_err': None,
                                     'drop_no_buf': None,
                                     'fifo_full': None,
                                     'lost': None,
                                     'no_ba': None,
                                     'orphan': None,
                                     'orphan_bad_ini': None,
                                     'orphan_bad_ini_free': None,
                                     'r0hole': None,
                                     'rlag': None,
                                     'rnhole': None,
                                     'rx_add_ba_resp': None,
                                     'rx_ba': None,
                                     'rx_del_ba': None,
                                     'rx_unexpect': None,
                                     'stuck': None,
                                     'stuck_ps': None,
                                     'tx_add_ba_req': None,
                                     'tx_bar': None,
                                     'tx_del_ba': None},ignore_index=True)
        
        ampdu_tx1 = ampdu_tx1.append({'block_data_fifo': None,
                                     'drop': None,
                                     'drop_err': None,
                                     'drop_no_buf': None,
                                     'fifo_full': None,
                                     'lost': None,
                                     'no_ba': None,
                                     'orphan': None,
                                     'orphan_bad_ini': None,
                                     'orphan_bad_ini_free': None,
                                     'r0hole': None,
                                     'rlag': None,
                                     'rnhole': None,
                                     'rx_add_ba_resp': None,
                                     'rx_ba': None,
                                     'rx_del_ba': None,
                                     'rx_unexpect': None,
                                     'stuck': None,
                                     'stuck_ps': None,
                                     'tx_add_ba_req': None,
                                     'tx_bar': None,
                                     'tx_del_ba': None},ignore_index=True)

        ampdu_tx2 = ampdu_tx2.append({'block_data_fifo': None,
                                     'drop': None,
                                     'drop_err': None,
                                     'drop_no_buf': None,
                                     'fifo_full': None,
                                     'lost': None,
                                     'no_ba': None,
                                     'orphan': None,
                                     'orphan_bad_ini': None,
                                     'orphan_bad_ini_free': None,
                                     'r0hole': None,
                                     'rlag': None,
                                     'rnhole': None,
                                     'rx_add_ba_resp': None,
                                     'rx_ba': None,
                                     'rx_del_ba': None,
                                     'rx_unexpect': None,
                                     'stuck': None,
                                     'stuck_ps': None,
                                     'tx_add_ba_req': None,
                                     'tx_bar': None,
                                     'tx_del_ba': None},ignore_index=True)
    else:
        for j, name in enumerate(data.head(length)[i].asDict()['radios']):
            max = j
        if max == 0:
            #print 'max=0'
            ampdu_tx0 = ampdu_tx0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['ampdu_tx'].asDict(), index = [i]))   
        elif max == 1:
            #print 'max=1'
            ampdu_tx0 = ampdu_tx0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['ampdu_tx'].asDict(), index = [i]))   
            ampdu_tx1 = ampdu_tx1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['ampdu_tx'].asDict(), index = [i]))
        elif max == 2:
            #print 'max=2'
            ampdu_tx0 = ampdu_tx0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['ampdu_tx'].asDict(), index = [i]))   
            ampdu_tx1 = ampdu_tx1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['ampdu_tx'].asDict(), index = [i]))
            ampdu_tx2 = ampdu_tx2.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][2].asDict()['ampdu_tx'].asDict(), index = [i]))
        else: 
            ampdu_tx0 = ampdu_tx0.append({'block_data_fifo': None,
                                         'drop': None,
                                         'drop_err': None,
                                         'drop_no_buf': None,
                                         'fifo_full': None,
                                         'lost': None,
                                         'no_ba': None,
                                         'orphan': None,
                                         'orphan_bad_ini': None,
                                         'orphan_bad_ini_free': None,
                                         'r0hole': None,
                                         'rlag': None,
                                         'rnhole': None,
                                         'rx_add_ba_resp': None,
                                         'rx_ba': None,
                                         'rx_del_ba': None,
                                         'rx_unexpect': None,
                                         'stuck': None,
                                         'stuck_ps': None,
                                         'tx_add_ba_req': None,
                                         'tx_bar': None,
                                         'tx_del_ba': None},ignore_index=True)
        
            ampdu_tx1 = ampdu_tx1.append({'block_data_fifo': None,
                                         'drop': None,
                                         'drop_err': None,
                                         'drop_no_buf': None,
                                         'fifo_full': None,
                                         'lost': None,
                                         'no_ba': None,
                                         'orphan': None,
                                         'orphan_bad_ini': None,
                                         'orphan_bad_ini_free': None,
                                         'r0hole': None,
                                         'rlag': None,
                                         'rnhole': None,
                                         'rx_add_ba_resp': None,
                                         'rx_ba': None,
                                         'rx_del_ba': None,
                                         'rx_unexpect': None,
                                         'stuck': None,
                                         'stuck_ps': None,
                                         'tx_add_ba_req': None,
                                         'tx_bar': None,
                                         'tx_del_ba': None},ignore_index=True)
        
            ampdu_tx2 = ampdu_tx2.append({'block_data_fifo': None,
                                         'drop': None,
                                         'drop_err': None,
                                         'drop_no_buf': None,
                                         'fifo_full': None,
                                         'lost': None,
                                         'no_ba': None,
                                         'orphan': None,
                                         'orphan_bad_ini': None,
                                         'orphan_bad_ini_free': None,
                                         'r0hole': None,
                                         'rlag': None,
                                         'rnhole': None,
                                         'rx_add_ba_resp': None,
                                         'rx_ba': None,
                                         'rx_del_ba': None,
                                         'rx_unexpect': None,
                                         'stuck': None,
                                         'stuck_ps': None,
                                         'tx_add_ba_req': None,
                                         'tx_bar': None,
                                         'tx_del_ba': None},ignore_index=True)

# %%
ampdu_tx1
# Out:
#     block_data_fifo  drop drop_err drop_no_buf fifo_full  lost no_ba orphan  \
# 0              None  None     None        None      None  None  None   None
# 1              None  None     None        None      None  None  None   None
# 2              None  None     None        None      None  None  None   None
# 3              None  None     None        None      None  None  None   None
# 4              None  None     None        None      None  None  None   None
# 5              None  None     None        None      None  None  None   None
# 6              None  None     None        None      None  None  None   None
# 7              None  None     None        None      None  None  None   None
# 8               238  None     None        None      None  None  None   None
# 9              None  None     None        None      None  None  None   None
# 10             None  None     None        None      None  None  None   None
# ...

# %%
''' cannot figure out how to do indexing... each loop will have one index, but to seperate radios into 3,
each row will have same index. Unless we assume radio for sure has 3, in that case we can force index for each ap +3 \
otherwise the indexing will be confused, given some records have <>3 radios

# Flatten Radio

radio  att1  att2
0
1
2


for i in range(10):
    print i
    for j, names in enumerate(data.head(length)[i].asDict()['radios'][i]):
        print j
        if data.head(length)[j].asDict()['radios'][i].asDict()['ampdu_tx'].asDict() == []:
            ampdu_tx.append({'block_data_fifo': None,
                                         'drop': None,
                                         'drop_err': None,
                                         'drop_no_buf': None,
                                         'fifo_full': None,
                                         'lost': None,
                                         'no_ba': None,
                                         'orphan': None,
                                         'orphan_bad_ini': None,
                                         'orphan_bad_ini_free': None,
                                         'r0hole': None,
                                         'rlag': None,
                                         'rnhole': None,
                                         'rx_add_ba_resp': None,
                                         'rx_ba': None,
                                         'rx_del_ba': None,
                                         'rx_unexpect': None,
                                         'stuck': None,
                                         'stuck_ps': None,
                                         'tx_add_ba_req': None,
                                         'tx_bar': None,
                                         'tx_del_ba': None},ignore_index=True)
        else:
            ampdu_tx = ampdu_tx.append(data.head(length)[j].asDict()['radios'][i].asDict()['ampdu_tx'].asDict(), index=[i])
    
'''
# Out:
# 0
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-677-89baf01e9a92> in <module>()
#      35                                          'tx_del_ba': None},ignore_index=True)
#      36         else:
# ---> 37             ampdu_tx = ampdu_tx.append(data.head(length)[j].asDict()['radios'][i].asDict()['ampdu_tx'].asDict(), index=[i])
#      38
#      39
#
# TypeError: append() got an unexpected keyword argument 'index'

# %%
#data.head(length)[1].asDict()['radios'][2].asDict()['ampdu_tx'].asDict()

# %%
#length = 10

counter0 = pd.DataFrame()
counter1 = pd.DataFrame()
counter2 = pd.DataFrame()

for i in range(length):
    #print i
    if data.head(length)[i].asDict()['radios'] == []:
        counter0 = counter0.append({'re_init': None,
                                         're_init_throttle': None,
                                         'rx_bytes': None,
                                         'rx_dups': None,
                                         'rx_errors': None,
                                         'rx_fifo_overflow': None,
                                         'rx_hl_fifo_overflow': None,
                                         'rx_hwprobe_req': None,
                                         'rx_hwprobe_req_qoverflow': None,
                                         'rx_mgmt': None,
                                         'rx_pkts': None,
                                         'rx_retried': None,
                                         'tx_bcmc2unicast': None,
                                         'tx_bcmc2unicast_bytes': None,
                                         'tx_bcmc2unicast_client': None,
                                         'tx_bcmc2unicast_client_bytes': None,
                                         'tx_bcn_intr': None,
                                         'tx_bytes': None,
                                         'tx_drop_arp': None,
                                         'tx_errors': None,
                                         'tx_failed': None,
                                         'tx_failed_arp': None,
                                         'tx_hwprobe_resp': None,
                                         'tx_hwprobe_resp_drop_timeout': None,
                                         'tx_hwprobe_resp_failed': None,
                                         'tx_mgmt': None,
                                         'tx_mgmt_dropped': None,
                                         'tx_phy_err': None,
                                         'tx_pkts': None,
                                         'tx_psblk_fifo': None,
                                         'tx_retried': None,
                                         'tx_retries': None,
                                         'tx_toss': None,
                                         'tx_toss_arp': None,
                                         'tx_toss_bcmc': None,
                                         'tx_toss_unicast': None},ignore_index=True)
        
        counter1 = counter1.append({'re_init': None,
                                         're_init_throttle': None,
                                         'rx_bytes': None,
                                         'rx_dups': None,
                                         'rx_errors': None,
                                         'rx_fifo_overflow': None,
                                         'rx_hl_fifo_overflow': None,
                                         'rx_hwprobe_req': None,
                                         'rx_hwprobe_req_qoverflow': None,
                                         'rx_mgmt': None,
                                         'rx_pkts': None,
                                         'rx_retried': None,
                                         'tx_bcmc2unicast': None,
                                         'tx_bcmc2unicast_bytes': None,
                                         'tx_bcmc2unicast_client': None,
                                         'tx_bcmc2unicast_client_bytes': None,
                                         'tx_bcn_intr': None,
                                         'tx_bytes': None,
                                         'tx_drop_arp': None,
                                         'tx_errors': None,
                                         'tx_failed': None,
                                         'tx_failed_arp': None,
                                         'tx_hwprobe_resp': None,
                                         'tx_hwprobe_resp_drop_timeout': None,
                                         'tx_hwprobe_resp_failed': None,
                                         'tx_mgmt': None,
                                         'tx_mgmt_dropped': None,
                                         'tx_phy_err': None,
                                         'tx_pkts': None,
                                         'tx_psblk_fifo': None,
                                         'tx_retried': None,
                                         'tx_retries': None,
                                         'tx_toss': None,
                                         'tx_toss_arp': None,
                                         'tx_toss_bcmc': None,
                                         'tx_toss_unicast': None},ignore_index=True)

        counter2 = counter2.append({'re_init': None,
                                         're_init_throttle': None,
                                         'rx_bytes': None,
                                         'rx_dups': None,
                                         'rx_errors': None,
                                         'rx_fifo_overflow': None,
                                         'rx_hl_fifo_overflow': None,
                                         'rx_hwprobe_req': None,
                                         'rx_hwprobe_req_qoverflow': None,
                                         'rx_mgmt': None,
                                         'rx_pkts': None,
                                         'rx_retried': None,
                                         'tx_bcmc2unicast': None,
                                         'tx_bcmc2unicast_bytes': None,
                                         'tx_bcmc2unicast_client': None,
                                         'tx_bcmc2unicast_client_bytes': None,
                                         'tx_bcn_intr': None,
                                         'tx_bytes': None,
                                         'tx_drop_arp': None,
                                         'tx_errors': None,
                                         'tx_failed': None,
                                         'tx_failed_arp': None,
                                         'tx_hwprobe_resp': None,
                                         'tx_hwprobe_resp_drop_timeout': None,
                                         'tx_hwprobe_resp_failed': None,
                                         'tx_mgmt': None,
                                         'tx_mgmt_dropped': None,
                                         'tx_phy_err': None,
                                         'tx_pkts': None,
                                         'tx_psblk_fifo': None,
                                         'tx_retried': None,
                                         'tx_retries': None,
                                         'tx_toss': None,
                                         'tx_toss_arp': None,
                                         'tx_toss_bcmc': None,
                                         'tx_toss_unicast': None},ignore_index=True)
            
    else:
        for j, name in enumerate(data.head(length)[i].asDict()['radios']):
            max = j
        if max == 0:
            #print 'max=0'
            counter0 = counter0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['counter'].asDict(), index = [i]))   
        elif max == 1:
            #print 'max=1'
            counter0 = counter0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['counter'].asDict(), index = [i]))   
            counter1 = counter1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['counter'].asDict(), index = [i]))
        elif max == 2:
            #print 'max=2'
            counter0 = counter0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['counter'].asDict(), index = [i]))   
            counter1 = counter1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['counter'].asDict(), index = [i]))
            counter2 = counter2.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][2].asDict()['counter'].asDict(), index = [i]))
        else: 
            counter0 = counter0.append({'re_init': None,
                                         're_init_throttle': None,
                                         'rx_bytes': None,
                                         'rx_dups': None,
                                         'rx_errors': None,
                                         'rx_fifo_overflow': None,
                                         'rx_hl_fifo_overflow': None,
                                         'rx_hwprobe_req': None,
                                         'rx_hwprobe_req_qoverflow': None,
                                         'rx_mgmt': None,
                                         'rx_pkts': None,
                                         'rx_retried': None,
                                         'tx_bcmc2unicast': None,
                                         'tx_bcmc2unicast_bytes': None,
                                         'tx_bcmc2unicast_client': None,
                                         'tx_bcmc2unicast_client_bytes': None,
                                         'tx_bcn_intr': None,
                                         'tx_bytes': None,
                                         'tx_drop_arp': None,
                                         'tx_errors': None,
                                         'tx_failed': None,
                                         'tx_failed_arp': None,
                                         'tx_hwprobe_resp': None,
                                         'tx_hwprobe_resp_drop_timeout': None,
                                         'tx_hwprobe_resp_failed': None,
                                         'tx_mgmt': None,
                                         'tx_mgmt_dropped': None,
                                         'tx_phy_err': None,
                                         'tx_pkts': None,
                                         'tx_psblk_fifo': None,
                                         'tx_retried': None,
                                         'tx_retries': None,
                                         'tx_toss': None,
                                         'tx_toss_arp': None,
                                         'tx_toss_bcmc': None,
                                         'tx_toss_unicast': None},ignore_index=True)
        
            counter1 = counter1.append({'re_init': None,
                                         're_init_throttle': None,
                                         'rx_bytes': None,
                                         'rx_dups': None,
                                         'rx_errors': None,
                                         'rx_fifo_overflow': None,
                                         'rx_hl_fifo_overflow': None,
                                         'rx_hwprobe_req': None,
                                         'rx_hwprobe_req_qoverflow': None,
                                         'rx_mgmt': None,
                                         'rx_pkts': None,
                                         'rx_retried': None,
                                         'tx_bcmc2unicast': None,
                                         'tx_bcmc2unicast_bytes': None,
                                         'tx_bcmc2unicast_client': None,
                                         'tx_bcmc2unicast_client_bytes': None,
                                         'tx_bcn_intr': None,
                                         'tx_bytes': None,
                                         'tx_drop_arp': None,
                                         'tx_errors': None,
                                         'tx_failed': None,
                                         'tx_failed_arp': None,
                                         'tx_hwprobe_resp': None,
                                         'tx_hwprobe_resp_drop_timeout': None,
                                         'tx_hwprobe_resp_failed': None,
                                         'tx_mgmt': None,
                                         'tx_mgmt_dropped': None,
                                         'tx_phy_err': None,
                                         'tx_pkts': None,
                                         'tx_psblk_fifo': None,
                                         'tx_retried': None,
                                         'tx_retries': None,
                                         'tx_toss': None,
                                         'tx_toss_arp': None,
                                         'tx_toss_bcmc': None,
                                         'tx_toss_unicast': None},ignore_index=True)

            counter2 = counter2.append({'re_init': None,
                                         're_init_throttle': None,
                                         'rx_bytes': None,
                                         'rx_dups': None,
                                         'rx_errors': None,
                                         'rx_fifo_overflow': None,
                                         'rx_hl_fifo_overflow': None,
                                         'rx_hwprobe_req': None,
                                         'rx_hwprobe_req_qoverflow': None,
                                         'rx_mgmt': None,
                                         'rx_pkts': None,
                                         'rx_retried': None,
                                         'tx_bcmc2unicast': None,
                                         'tx_bcmc2unicast_bytes': None,
                                         'tx_bcmc2unicast_client': None,
                                         'tx_bcmc2unicast_client_bytes': None,
                                         'tx_bcn_intr': None,
                                         'tx_bytes': None,
                                         'tx_drop_arp': None,
                                         'tx_errors': None,
                                         'tx_failed': None,
                                         'tx_failed_arp': None,
                                         'tx_hwprobe_resp': None,
                                         'tx_hwprobe_resp_drop_timeout': None,
                                         'tx_hwprobe_resp_failed': None,
                                         'tx_mgmt': None,
                                         'tx_mgmt_dropped': None,
                                         'tx_phy_err': None,
                                         'tx_pkts': None,
                                         'tx_psblk_fifo': None,
                                         'tx_retried': None,
                                         'tx_retries': None,
                                         'tx_toss': None,
                                         'tx_toss_arp': None,
                                         'tx_toss_bcmc': None,
                                         'tx_toss_unicast': None},ignore_index=True)

# %%
data.head(length)[1].asDict()['radios'][0].asDict()['counter'].asDict()
# Out:
# {'re_init': None,
#  're_init_throttle': None,
#  'rx_bytes': 2816424,
#  'rx_dups': None,
#  'rx_errors': None,
#  'rx_fifo_overflow': None,
#  'rx_hl_fifo_overflow': None,
#  'rx_hwprobe_req': None,
#  'rx_hwprobe_req_qoverflow': None,
#  'rx_mgmt': 3108,
#  'rx_pkts': 2874,
#  'rx_retried': 206,
#  'tx_bcmc2unicast': None,
#  'tx_bcmc2unicast_bytes': None,
#  'tx_bcmc2unicast_client': None,
#  'tx_bcmc2unicast_client_bytes': None,
#  'tx_bcn_intr': 606,
#  'tx_bytes': 499930,
#  'tx_drop_arp': None,
#  'tx_errors': None,
#  'tx_failed': None,
#  'tx_failed_arp': None,
#  'tx_hwprobe_resp': None,
#  'tx_hwprobe_resp_drop_timeout': None,
#  'tx_hwprobe_resp_failed': None,
#  'tx_mgmt': 1041,
#  'tx_mgmt_dropped': None,
#  'tx_phy_err': None,
#  'tx_pkts': 1041,
#  'tx_psblk_fifo': None,
#  'tx_retried': None,
#  'tx_retries': None,
#  'tx_toss': 4412,
#  'tx_toss_arp': None,
#  'tx_toss_bcmc': None,
#  'tx_toss_unicast': None}

# %%
#some radios records don't have non_aggr_regulate 

non_aggr_regulate0 = pd.DataFrame()
non_aggr_regulate1 = pd.DataFrame()
non_aggr_regulate2 = pd.DataFrame()

for i in range(length):
    #print i
    if data.head(length)[i].asDict()['radios'] == []:
        #print i
        non_aggr_regulate0 = non_aggr_regulate0.append({'dequeued': None, 'dropped': None, 'held': None, 'queued': None},ignore_index=True)
        
        non_aggr_regulate1 = non_aggr_regulate1.append({'dequeued': None, 'dropped': None, 'held': None, 'queued': None},ignore_index=True)
        
        non_aggr_regulate2 = non_aggr_regulate2.append({'dequeued': None, 'dropped': None, 'held': None, 'queued': None},ignore_index=True)
    else:
        for j, name in enumerate(data.head(length)[i].asDict()['radios']):
            max = j
        if max == 0:
            #print 'max=0'
            if data.head(length)[i].asDict()['radios'][0].asDict()['non_aggr_regulate'] is None:
                non_aggr_regulate0 = non_aggr_regulate0.append({'dequeued': None, 'dropped': None, 'held': None, 'queued': None},ignore_index=True)
            else:
                non_aggr_regulate0 = non_aggr_regulate0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['non_aggr_regulate'].asDict(), index = [i]))   
        elif max == 1:
            #print 'max=1'
            if data.head(length)[i].asDict()['radios'][0].asDict()['non_aggr_regulate'] is None:
                non_aggr_regulate0 = non_aggr_regulate0.append({'dequeued': None, 'dropped': None, 'held': None, 'queued': None},ignore_index=True)
            else: 
                non_aggr_regulate0 = non_aggr_regulate0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['non_aggr_regulate'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][1].asDict()['non_aggr_regulate'] is None:
                non_aggr_regulate1 = non_aggr_regulate1.append({'dequeued': None, 'dropped': None, 'held': None, 'queued': None},ignore_index=True)
            else:
                non_aggr_regulate1 = non_aggr_regulate1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['non_aggr_regulate'].asDict(), index = [i]))
        elif max == 2:
            #print 'max=2'
            if data.head(length)[i].asDict()['radios'][0].asDict()['non_aggr_regulate'] is None:
                non_aggr_regulate0 = non_aggr_regulate0.append({'dequeued': None, 'dropped': None, 'held': None, 'queued': None},ignore_index=True)
            else: 
                non_aggr_regulate0 = non_aggr_regulate0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['non_aggr_regulate'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][1].asDict()['non_aggr_regulate'] is None:
                non_aggr_regulate1 = non_aggr_regulate1.append({'dequeued': None, 'dropped': None, 'held': None, 'queued': None},ignore_index=True)
            else:
                non_aggr_regulate1 = non_aggr_regulate1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['non_aggr_regulate'].asDict(), index = [i]))
            if data.head(length)[i].asDict()['radios'][2].asDict()['non_aggr_regulate'] is None:
                non_aggr_regulate1 = non_aggr_regulate1.append({'dequeued': None, 'dropped': None, 'held': None, 'queued': None},ignore_index=True)
            else:
                non_aggr_regulate2 = non_aggr_regulate1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][2].asDict()['non_aggr_regulate'].asDict(), index = [i]))
        else: 
            non_aggr_regulate0 = non_aggr_regulate0.append({'dequeued': None, 'dropped': None, 'held': None, 'queued': None},ignore_index=True)
        
            non_aggr_regulate1 = non_aggr_regulate1.append({'dequeued': None, 'dropped': None, 'held': None, 'queued': None},ignore_index=True)
        
            non_aggr_regulate2 = non_aggr_regulate2.append({'dequeued': None, 'dropped': None, 'held': None, 'queued': None},ignore_index=True)
# Out:
# 7
# 12
# 14
# 19
# 29
# 30
# 32
# 39
# 40
# 46
# 48
# 49
# 52
# 54
# 56
# 58
# 62
# 70
# 73
# 77
# 78
# 84
# 89
# 94
# 104
# 105
# 107
# 108
# 113
# 115
# 117
# 120
# 122
# 123
# 126
# 129
# 130
# 131
# 138
# 141
# 142
# 145
# 147
# 148
# 149
# 151
# 153
# 173
# 177
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 191
# 198
# 200
# 201
# 202
# 203
# 204
# 205
# 211
# 217
# 218
# 219
# 225
# 226
# 227
# 228
# 234
# 236
# 239
# 241
# 243
# 244
# 246
# 250
# 252
# 256
# 259
# 260
# 261
# 266
# 267
# 269
# 271
# 274
# 276
# 277
# 279
# 283
# 287
# 290
# 294
# 295
# 298
# 303
# 305
# 306
# 308
# 311
# 312
# 314
# 317
# 320
# 322

# %%
non_aggr_regulate2
# Out:
#     dequeued dropped   held  queued
# 0        238    None   None     238
# 1     124670    1955  32837  128566
# 2        371    None   None     371
# 3       9242    None   1387    9299
# 4       None    None   None    None
# 5     241553     399  21501  246504
# 6     241553     399  21501  246504
# 7       None    None   None    None
# 8       None    None   None    None
# 9         33    None   None      33
# 10      None    None   None    None
# 11      None    None   None    None
# 12      None    None   None    None
# 13      None    None   None    None
# 14      None    None   None    None
# 15      None    None   None    None
# 16      3632      63   1654    3857
# 17       374    None   None     374
# 18      None    None   None    None
# 19      None    None   None    None
# 20      None    None   None    None
# 21      None    None   None    None
# 22      None    None   None    None
# 23      None    None   None    None
# 24      3632      63   1654    3857
# ...

# %%
#data.head(length)[71].asDict()['radios'][1].asDict()['non_aggr_regulate'] is None
# Out:
# True

# %%
pkt_pend0 = pd.DataFrame()
pkt_pend1 = pd.DataFrame()
pkt_pend2 = pd.DataFrame()

for i in range(length):
    #print i
    if data.head(length)[i].asDict()['radios'] == []:
        pkt_pend0 = pkt_pend0.append({'all': None,
                                     'ampdu': None,
                                     'amsdu': None,
                                     'atim': None,
                                     'bcmc': None,
                                     'be': None,
                                     'bk': None,
                                     'common': None,
                                     'hw': None,
                                     'ps': None,
                                     'vi': None,
                                     'vo': None},ignore_index=True)
        
        pkt_pend1 = pkt_pend1.append({'all': None,
                                     'ampdu': None,
                                     'amsdu': None,
                                     'atim': None,
                                     'bcmc': None,
                                     'be': None,
                                     'bk': None,
                                     'common': None,
                                     'hw': None,
                                     'ps': None,
                                     'vi': None,
                                     'vo': None},ignore_index=True)

        pkt_pend2 = pkt_pend2.append({'all': None,
                                     'ampdu': None,
                                     'amsdu': None,
                                     'atim': None,
                                     'bcmc': None,
                                     'be': None,
                                     'bk': None,
                                     'common': None,
                                     'hw': None,
                                     'ps': None,
                                     'vi': None,
                                     'vo': None},ignore_index=True)
    else:
        for j, name in enumerate(data.head(length)[i].asDict()['radios']):
            max = j
        if max == 0:
            if data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'] is None:
                pkt_pend0 = pkt_pend0.append({'all': None,
                                                     'ampdu': None,
                                                     'amsdu': None,
                                                     'atim': None,
                                                     'bcmc': None,
                                                     'be': None,
                                                     'bk': None,
                                                     'common': None,
                                                     'hw': None,
                                                     'ps': None,
                                                     'vi': None,
                                                     'vo': None},ignore_index=True)
            else:
                pkt_pend0 = pkt_pend0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'].asDict(), index = [i]))   
        elif max == 1:
            if data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'] is None:
                pkt_pend0 = pkt_pend0.append({'all': None,
                                                     'ampdu': None,
                                                     'amsdu': None,
                                                     'atim': None,
                                                     'bcmc': None,
                                                     'be': None,
                                                     'bk': None,
                                                     'common': None,
                                                     'hw': None,
                                                     'ps': None,
                                                     'vi': None,
                                                     'vo': None},ignore_index=True)
            else:
                pkt_pend0 = pkt_pend0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][1].asDict()['pkt_pend'] is None:
                pkt_pend1 = pkt_pend1.append({'all': None,
                                                     'ampdu': None,
                                                     'amsdu': None,
                                                     'atim': None,
                                                     'bcmc': None,
                                                     'be': None,
                                                     'bk': None,
                                                     'common': None,
                                                     'hw': None,
                                                     'ps': None,
                                                     'vi': None,
                                                     'vo': None},ignore_index=True)
            else:
                pkt_pend1 = pkt_pend1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['pkt_pend'].asDict(), index = [i]))   
        
        elif max == 2:
            if data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'] is None:
                pkt_pend0 = pkt_pend0.append({'all': None,
                                                     'ampdu': None,
                                                     'amsdu': None,
                                                     'atim': None,
                                                     'bcmc': None,
                                                     'be': None,
                                                     'bk': None,
                                                     'common': None,
                                                     'hw': None,
                                                     'ps': None,
                                                     'vi': None,
                                                     'vo': None},ignore_index=True)
            else:
                pkt_pend0 = pkt_pend0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][1].asDict()['pkt_pend'] is None:
                pkt_pend1 = pkt_pend1.append({'all': None,
                                                     'ampdu': None,
                                                     'amsdu': None,
                                                     'atim': None,
                                                     'bcmc': None,
                                                     'be': None,
                                                     'bk': None,
                                                     'common': None,
                                                     'hw': None,
                                                     'ps': None,
                                                     'vi': None,
                                                     'vo': None},ignore_index=True)
            else:
                pkt_pend1 = pkt_pend1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['pkt_pend'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][2].asDict()['pkt_pend'] is None:
                pkt_pend2 = pkt_pend2.append({'all': None,
                                                     'ampdu': None,
                                                     'amsdu': None,
                                                     'atim': None,
                                                     'bcmc': None,
                                                     'be': None,
                                                     'bk': None,
                                                     'common': None,
                                                     'hw': None,
                                                     'ps': None,
                                                     'vi': None,
                                                     'vo': None},ignore_index=True)
            else:
                pkt_pend2 = pkt_pend2.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][2].asDict()['pkt_pend'].asDict(), index = [i]))   
               
        else: 
            pkt_pend0 = pkt_pend0.append({'all': None,
                                     'ampdu': None,
                                     'amsdu': None,
                                     'atim': None,
                                     'bcmc': None,
                                     'be': None,
                                     'bk': None,
                                     'common': None,
                                     'hw': None,
                                     'ps': None,
                                     'vi': None,
                                     'vo': None},ignore_index=True)
        
            pkt_pend1 = pkt_pend1.append({'all': None,
                                     'ampdu': None,
                                     'amsdu': None,
                                     'atim': None,
                                     'bcmc': None,
                                     'be': None,
                                     'bk': None,
                                     'common': None,
                                     'hw': None,
                                     'ps': None,
                                     'vi': None,
                                     'vo': None},ignore_index=True)

            pkt_pend2 = pkt_pend2.append({'all': None,
                                     'ampdu': None,
                                     'amsdu': None,
                                     'atim': None,
                                     'bcmc': None,
                                     'be': None,
                                     'bk': None,
                                     'common': None,
                                     'hw': None,
                                     'ps': None,
                                     'vi': None,
                                     'vo': None},ignore_index=True)

# %%
data.head(length)[1].asDict()['radios'][0].asDict()['pkt_pend'].asDict()
# Out:
# {'all': None,
#  'ampdu': None,
#  'amsdu': None,
#  'atim': None,
#  'bcmc': None,
#  'be': None,
#  'bk': None,
#  'common': None,
#  'hw': None,
#  'ps': None,
#  'vi': None,
#  'vo': None}

# %%
pkt_pend2
# Out:
#       all ampdu amsdu  atim  bcmc    be    bk common    hw    ps    vi    vo
# 0    None  None  None  None  None  None  None   None  None  None  None  None
# 1    None  None  None  None  None  None  None   None  None  None  None  None
# 2    None  None  None  None  None  None  None   None  None  None  None  None
# 3    None  None  None  None  None  None  None   None  None  None  None  None
# 4    None  None  None  None  None  None  None   None  None  None  None  None
# 5    None  None  None  None  None  None  None   None  None  None  None  None
# 6    None  None  None  None  None  None  None   None  None  None  None  None
# 7    None  None  None  None  None  None  None   None  None  None  None  None
# 8    None  None  None  None  None  None  None   None  None  None  None  None
# 9    None  None  None  None  None  None  None   None  None  None  None  None
# 10   None  None  None  None  None  None  None   None  None  None  None  None
# ...

# %%
#length = 10
'''
pkt_pend0 = pd.DataFrame()
pkt_pend1 = pd.DataFrame()
pkt_pend2 = pd.DataFrame()

def pkt_pend0f():
    pkt_pend0 = pkt_pend0.append({'all': None,
                                     'ampdu': None,
                                     'amsdu': None,
                                     'atim': None,
                                     'bcmc': None,
                                     'be': None,
                                     'bk': None,
                                     'common': None,
                                     'hw': None,
                                     'ps': None,
                                     'vi': None,
                                     'vo': None},ignore_index=True)
def pkt_pend1f():
    pkt_pend1 = pkt_pend1.append({'all': None,
                                     'ampdu': None,
                                     'amsdu': None,
                                     'atim': None,
                                     'bcmc': None,
                                     'be': None,
                                     'bk': None,
                                     'common': None,
                                     'hw': None,
                                     'ps': None,
                                     'vi': None,
                                     'vo': None},ignore_index=True)

def pkt_pend2f():
    pkt_pend2 = pkt_pend2.append({'all': None,
                                     'ampdu': None,
                                     'amsdu': None,
                                     'atim': None,
                                     'bcmc': None,
                                     'be': None,
                                     'bk': None,
                                     'common': None,
                                     'hw': None,
                                     'ps': None,
                                     'vi': None,
                                     'vo': None},ignore_index=True)
    
for i in range(length):
    #print i
    if data.head(length)[i].asDict()['radios'] == []:
        pkt_pend0f()
        pkt_pend1f()
        pkt_pend2f()        
    else:
        for j, name in enumerate(data.head(length)[i].asDict()['radios']):
            max = j
        if max == 0:
            if data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'] is None:
                pkt_pend0f()
            else:
                pkt_pend0 = pkt_pend0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'].asDict(), index = [i]))   
        elif max == 1:
            if data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'] is None:
                pkt_pend0f() 
            else:
                pkt_pend0 = pkt_pend0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][1].asDict()['pkt_pend'] is None:
                pkt_pend1f() 
            else:
                pkt_pend1 = pkt_pend1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'].asDict(), index = [i]))   
        
        elif max == 2:
            if data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'] is None:
                pkt_pend0f()
            else:
                pkt_pend0 = pkt_pend0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][1].asDict()['pkt_pend'] is None:
                pkt_pend1f()
            else:
                pkt_pend1 = pkt_pend1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][2].asDict()['pkt_pend'] is None:
                pkt_pend2f()
            else:
                pkt_pend2 = pkt_pend2.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pkt_pend'].asDict(), index = [i]))   
               
        else: 
            pkt_pend0f()
            pkt_pend1f()
            pkt_pend2f()
'''
# Out:
# "\npkt_pend0 = pd.DataFrame()\npkt_pend1 = pd.DataFrame()\npkt_pend2 = pd.DataFrame()\n\ndef pkt_pend0f():\n    pkt_pend0 = pkt_pend0.append({'all': None,\n                                     'ampdu': None,\n                                     'amsdu': None,\n                                     'atim': None,\n                                     'bcmc': None,\n                                     'be': None,\n                                     'bk': None,\n                                     'common': None,\n                                     'hw': None,\n                                     'ps': None,\n                                     'vi': None,\n                                     'vo': None},ignore_index=True)\ndef pkt_pend1f():\n    pkt_pend1 = pkt_pend1.append({'all': None,\n                                     'ampdu': None,\n                                     'amsdu': None,\n                                     'atim': None,\n                                  
# ...

# %%
#length = 10

'''
pq0 = pd.DataFrame()
pq1 = pd.DataFrame()
pq2 = pd.DataFrame()

def pq0f():
    nonlocal pq0
    pq0 = pq0.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)
def pq1f():
    nonlocal pq1 
    pq1 = pq0.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)
def pq2f():
    nonlocal pq2
    pq2 = pq0.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)

for i in range(length):
    #print i
    if data.head(length)[i].asDict()['radios'] == []:
        pq0f()
        pq1f()
        pq2f()        
    else:
        for j, name in enumerate(data.head(length)[i].asDict()['radios']):
            max = j
        if max == 0:
            if data.head(length)[i].asDict()['radios'][0].asDict()['pq'] is None:
                pq0f()
            else:
                pq0 = pq0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pq'].asDict(), index = [i]))   
        elif max == 1:
            if data.head(length)[i].asDict()['radios'][0].asDict()['pq'] is None:
                pq0f() 
            else:
                pq0 = pq0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pq'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][1].asDict()['pq'] is None:
                pq1f() 
            else:
                pq1 = pq1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pq'].asDict(), index = [i]))   
        
        elif max == 2:
            if data.head(length)[i].asDict()['radios'][0].asDict()['pq'] is None:
                pq0f()
            else:
                pq0 = pq0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pq'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][1].asDict()['pq'] is None:
                pq1f()
            else:
                pq1 = pq1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pq'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][2].asDict()['pq'] is None:
                pq2f()
            else:
                pq2 = pq2.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pq'].asDict(), index = [i]))   
               
        else: 
            pq0f()
            pq1f()
            pq2f()
'''
# Out:
#   File "<ipython-input-722-d8572344ea68>", line 7
#     nonlocal pq0
#                ^
# SyntaxError: invalid syntax

# %%
pq0 = pd.DataFrame()
pq1 = pd.DataFrame()
pq2 = pd.DataFrame()

for i in range(length):
    #print i
    if data.head(length)[i].asDict()['radios'] == []:
        pq0 = pq0.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)
        
        pq1 = pq1.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)

        pq2 = pq2.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)
    else:
        for j, name in enumerate(data.head(length)[i].asDict()['radios']):
            max = j
        if max == 0:
            if data.head(length)[i].asDict()['radios'][0].asDict()['pq'] is None:
                pq0 = pq0.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)
            else:
                pq0 = pq0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pq'].asDict(), index = [i]))   
        elif max == 1:
            if data.head(length)[i].asDict()['radios'][0].asDict()['pq'] is None:
                pq0 = pq0.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)
            else:
                pq0 = pq0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pq'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][0].asDict()['pq'] is None:
                pq1 = pq1.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)
            else:
                pq1 = pq1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['pq'].asDict(), index = [i]))   

        elif max == 2:
            if data.head(length)[i].asDict()['radios'][0].asDict()['pq'] is None:
                pq0 = pq0.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)
            else:
                pq0 = pq0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['pq'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][0].asDict()['pq'] is None:
                pq1 = pq1.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)
            else:
                pq1 = pq1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['pq'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][0].asDict()['pq'] is None:
                pq2 = pq2.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)
            else:
                pq2 = pq2.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][2].asDict()['pq'].asDict(), index = [i]))   

        else: 
            pq0 = pq0.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)

            pq1 = pq1.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)

            pq2 = pq2.append({'dropped': None, 'full_dropped': None, 'requested': None, 'retried': None},ignore_index=True)

# %%
pq2
# Out:
#     dropped full_dropped requested retried
# 0      None         None      None    None
# 1      None         None      1041     331
# 2      None         None      None    None
# 3      None         None       234       1
# 4      None         None      None    None
# 5      None         None        12    None
# 6      None         None         3    None
# 7      None         None      None    None
# 8      None         None      None    None
# 9      None         None      None    None
# 10     None         None      None    None
# 11     None         None      None    None
# 12     None         None         2    None
# 13     None         None      None    None
# 14     None         None         1    None
# 15     None         None       284       3
# 16     None         None      None    None
# 17     None         None      None    None
# 18     None         None      None    None
# 19     None         None        35    None
# 20     None         None         2    None
# ...

# %%
data.head(length)[1].asDict()['radios'][0].asDict()['pq'].asDict()
# Out:
# {'dropped': None, 'full_dropped': None, 'requested': 1041, 'retried': 331}

# %%
probe_counter0 = pd.DataFrame()
probe_counter1 = pd.DataFrame()
probe_counter2 = pd.DataFrame()

for i in range(length):
    #print i
    if data.head(length)[i].asDict()['radios'] == []:
        probe_counter0 = probe_counter0.append({'ignore_probe_req_min_rssi': None,
                                                 'rx_probe_req_bc': None,
                                                 'rx_probe_req_non_bc': None,
                                                 'rx_probe_req_rand': None,
                                                 'tx_probe_resp_sw': None},ignore_index=True)
        probe_counter1 = probe_counter1.append({'ignore_probe_req_min_rssi': None,
                                                 'rx_probe_req_bc': None,
                                                 'rx_probe_req_non_bc': None,
                                                 'rx_probe_req_rand': None,
                                                 'tx_probe_resp_sw': None},ignore_index=True)
        probe_counter2 = probe_counter2.append({'ignore_probe_req_min_rssi': None,
                                                 'rx_probe_req_bc': None,
                                                 'rx_probe_req_non_bc': None,
                                                 'rx_probe_req_rand': None,
                                                 'tx_probe_resp_sw': None},ignore_index=True)
    else:
        for j, name in enumerate(data.head(length)[i].asDict()['radios']):
            max = j
        if max == 0:
            if data.head(length)[i].asDict()['radios'][0].asDict()['probe_counter'] is None:
                probe_counter0 = probe_counter0.append({'ignore_probe_req_min_rssi': None,
                                                 'rx_probe_req_bc': None,
                                                 'rx_probe_req_non_bc': None,
                                                 'rx_probe_req_rand': None,
                                                 'tx_probe_resp_sw': None},ignore_index=True)
            else:
                probe_counter0 = probe_counter0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['probe_counter'].asDict(), index = [i]))   
        elif max == 1:
            if data.head(length)[i].asDict()['radios'][0].asDict()['probe_counter'] is None:
                probe_counter0 = probe_counter0.append({'ignore_probe_req_min_rssi': None,
                                                 'rx_probe_req_bc': None,
                                                 'rx_probe_req_non_bc': None,
                                                 'rx_probe_req_rand': None,
                                                 'tx_probe_resp_sw': None},ignore_index=True)
            else:
                probe_counter0 = probe_counter0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['probe_counter'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][1].asDict()['probe_counter'] is None:
                probe_counter1 = probe_counter1.append({'ignore_probe_req_min_rssi': None,
                                                 'rx_probe_req_bc': None,
                                                 'rx_probe_req_non_bc': None,
                                                 'rx_probe_req_rand': None,
                                                 'tx_probe_resp_sw': None},ignore_index=True)
            else:
                probe_counter1 = probe_counter1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['probe_counter'].asDict(), index = [i]))   

        elif max == 2:
            if data.head(length)[i].asDict()['radios'][0].asDict()['probe_counter'] is None:
                probe_counter0 = probe_counter0.append({'ignore_probe_req_min_rssi': None,
                                                 'rx_probe_req_bc': None,
                                                 'rx_probe_req_non_bc': None,
                                                 'rx_probe_req_rand': None,
                                                 'tx_probe_resp_sw': None},ignore_index=True)
            else:
                probe_counter0 = probe_counter0.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][0].asDict()['probe_counter'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][1].asDict()['probe_counter'] is None:
                probe_counter1 = probe_counter1.append({'ignore_probe_req_min_rssi': None,
                                                 'rx_probe_req_bc': None,
                                                 'rx_probe_req_non_bc': None,
                                                 'rx_probe_req_rand': None,
                                                 'tx_probe_resp_sw': None},ignore_index=True)
            else:
                probe_counter1 = probe_counter1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][1].asDict()['probe_counter'].asDict(), index = [i]))   
            if data.head(length)[i].asDict()['radios'][2].asDict()['probe_counter'] is None:
                probe_counter2 = probe_counter1.append({'ignore_probe_req_min_rssi': None,
                                                 'rx_probe_req_bc': None,
                                                 'rx_probe_req_non_bc': None,
                                                 'rx_probe_req_rand': None,
                                                 'tx_probe_resp_sw': None},ignore_index=True)
            else:
                probe_counter2 = probe_counter1.append(pd.DataFrame(data.head(length)[i].asDict()['radios'][2].asDict()['probe_counter'].asDict(), index = [i]))   

        else: 
            probe_counter0 = probe_counter0.append({'ignore_probe_req_min_rssi': None,
                                                 'rx_probe_req_bc': None,
                                                 'rx_probe_req_non_bc': None,
                                                 'rx_probe_req_rand': None,
                                                 'tx_probe_resp_sw': None},ignore_index=True)
            probe_counter1 = probe_counter1.append({'ignore_probe_req_min_rssi': None,
                                                 'rx_probe_req_bc': None,
                                                 'rx_probe_req_non_bc': None,
                                                 'rx_probe_req_rand': None,
                                                 'tx_probe_resp_sw': None},ignore_index=True)
            probe_counter2 = probe_counter2.append({'ignore_probe_req_min_rssi': None,
                                                 'rx_probe_req_bc': None,
                                                 'rx_probe_req_non_bc': None,
                                                 'rx_probe_req_rand': None,
                                                 'tx_probe_resp_sw': None},ignore_index=True)

# %%
data.head(length)[1].asDict()['radios'][0].asDict()['probe_counter'].asDict()
# Out:
# {'ignore_probe_req_min_rssi': None,
#  'rx_probe_req_bc': 2708389,
#  'rx_probe_req_non_bc': 451,
#  'rx_probe_req_rand': None,
#  'tx_probe_resp_sw': 1264835}

# %%
probe_counter2
# Out:
#     ignore_probe_req_min_rssi rx_probe_req_bc rx_probe_req_non_bc  \
# 0                        None            None                None
# 1                        None         2708389                 451
# 2                        None            None                None
# 3                        None           49891                None
# 4                        None         1694962                None
# 5                        None          944942                  81
# 6                        None          944942                  81
# 7                        None            None                None
# 8                        None            None                None
# 9                        None            None                None
# 10                       None          844088                 281
# 11                       None            None                None
# 12                       None            None                None
# ...

# %%
#per_antenna_rssi = per_antenna_rssi.append(pd.DataFrame({'per_antenna_rssi': [data.head(length)[1].asDict()['radios'][0].asDict()['per_antenna_rssi']]}))   

per_antenna_rssi0 = pd.DataFrame()
per_antenna_rssi1 = pd.DataFrame()
per_antenna_rssi2 = pd.DataFrame()

for i in range(length):
    #print i
    if data.head(length)[i].asDict()['radios'] == []:
        per_antenna_rssi0 = per_antenna_rssi0.append(pd.DataFrame({'per_antenna_rssi': []}))      
        per_antenna_rssi1 = per_antenna_rssi1.append(pd.DataFrame({'per_antenna_rssi': []}))      
        per_antenna_rssi2 = per_antenna_rssi2.append(pd.DataFrame({'per_antenna_rssi': []}))      
    else:
        for j, name in enumerate(data.head(length)[i].asDict()['radios']):
            max = j
        if max == 0:
            if data.head(length)[i].asDict()['radios'][0].asDict()['per_antenna_rssi'] is None:
                per_antenna_rssi0 = per_antenna_rssi0.append([],ignore_index=True)
            else:
                per_antenna_rssi0 = per_antenna_rssi0.append(pd.DataFrame({'per_antenna_rssi': [data.head(length)[i].asDict()['radios'][0].asDict()['per_antenna_rssi']]}, index = [i]))   
        elif max == 1:
            if data.head(length)[i].asDict()['radios'][0].asDict()['per_antenna_rssi'] is None:
                per_antenna_rssi0 = per_antenna_rssi0.append([],ignore_index=True)
            else:
                per_antenna_rssi0 = per_antenna_rssi0.append(pd.DataFrame({'per_antenna_rssi': [data.head(length)[i].asDict()['radios'][0].asDict()['per_antenna_rssi']]}, index = [i]))   

            if data.head(length)[i].asDict()['radios'][1].asDict()['per_antenna_rssi'] is None:
                per_antenna_rssi1 = per_antenna_rssi1.append([],ignore_index=True)
            else: 
                per_antenna_rssi1 = per_antenna_rssi1.append(pd.DataFrame({'per_antenna_rssi': [data.head(length)[i].asDict()['radios'][1].asDict()['per_antenna_rssi']]}, index = [i]))   
        elif max == 2:
            if data.head(length)[i].asDict()['radios'][0].asDict()['per_antenna_rssi'] is None:
                per_antenna_rssi0 = per_antenna_rssi0.append([],ignore_index=True)
            else:
                per_antenna_rssi0 = per_antenna_rssi0.append(pd.DataFrame({'per_antenna_rssi': [data.head(length)[i].asDict()['radios'][0].asDict()['per_antenna_rssi']]}, index = [i]))   
            if data.head(length)[i].asDict()['radios'][1].asDict()['per_antenna_rssi'] is None:
                per_antenna_rssi1 = per_antenna_rssi0.append([],ignore_index=True)
            else:
                per_antenna_rssi1 = per_antenna_rssi0.append(pd.DataFrame({'per_antenna_rssi': [data.head(length)[i].asDict()['radios'][1].asDict()['per_antenna_rssi']]}, index = [i]))   
            if data.head(length)[i].asDict()['radios'][2].asDict()['per_antenna_rssi'] is None:
                per_antenna_rssi2 = per_antenna_rssi0.append([],ignore_index=True)
            else:
                per_antenna_rssi2 = per_antenna_rssi0.append(pd.DataFrame({'per_antenna_rssi': [data.head(length)[i].asDict()['radios'][2].asDict()['per_antenna_rssi']]}, index = [i]))   
        else: 
            per_antenna_rssi0 = per_antenna_rssi0.append(pd.DataFrame({'per_antenna_rssi': []}))      
            per_antenna_rssi1 = per_antenna_rssi1.append(pd.DataFrame({'per_antenna_rssi': []}))      
            per_antenna_rssi2 = per_antenna_rssi2.append(pd.DataFrame({'per_antenna_rssi': []}))

# %%
per_antenna_rssi = per_antenna_rssi.append(pd.DataFrame({'per_antenna_rssi': [data.head(length)[1].asDict()['radios'][0].asDict()['per_antenna_rssi']]}))   

for i in range(length):
    print data.head(length)[i].asDict()['radios'][0].asDict()['per_antenna_rssi']
# Out:
# [-64, -63, -63, -65]
# [-68, -74, -64, -62]
# [0, 0, 0, 0]
# [-66, -72, 0, 0]
# [-85, -84, -87, -87]
# [-92, -93, -91, -92]
# [-92, -93, -91, -92]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-727-5a4fc2de5adb> in <module>()
#       1 for i in range(length):
# ----> 2     print data.head(length)[i].asDict()['radios'][0].asDict()['per_antenna_rssi']
#
# IndexError: list index out of range

# %%
data.head(length)[7].asDict()['radios'][0].asDict()['per_antenna_rssi']
# Out:
# []

# %%
#ampdu_rx = pd.DataFrame()
#ampdu_rx = ampdu_rx.append(pd.DataFrame(data.head(length)[1].asDict()['radios'][0].asDict()['ampdu_rx'].asDict(), index = [1]))

# %%
#ampdu_tx = pd.DataFrame()
#ampdu_tx = ampdu_tx.append(pd.DataFrame(data.head(length)[1].asDict()['radios'][0].asDict()['ampdu_tx'].asDict(), index = [1]))

# %%
#counter = pd.DataFrame()
#counter = counter.append(pd.DataFrame(data.head(length)[1].asDict()['radios'][0].asDict()['counter'].asDict(), index = [1]))

# %%
#non_aggr_regulate = pd.DataFrame()
#non_aggr_regulate = non_aggr_regulate.append(pd.DataFrame(data.head(length)[1].asDict()['radios'][0].asDict()['non_aggr_regulate'].asDict(), index = [1]))

# %%
#pkt_pend = pd.DataFrame()
#pkt_pend = pkt_pend.append(pd.DataFrame(data.head(length)[1].asDict()['radios'][0].asDict()['pkt_pend'].asDict(), index = [1]))

# %%
#pq = pd.DataFrame()
#pq = pq.append(pd.DataFrame(data.head(length)[1].asDict()['radios'][0].asDict()['pq'].asDict(), index = [1]))

# %%
#probe_counter = pd.DataFrame()
#probe_counter = probe_counter.append(pd.DataFrame(data.head(length)[1].asDict()['radios'][0].asDict()['probe_counter'].asDict(), index = [1]))

# %%
per_antenna_rssi = pd.DataFrame()
per_antenna_rssi = per_antenna_rssi.append(pd.DataFrame({'per_antenna_rssi': [data.head(length)[1].asDict()['radios'][0].asDict()['per_antenna_rssi']]}))

# %%
# 21 attributes
moreattr = pd.DataFrame()
for i in range(1):
    
    for each in ['band','bandwidth','channel','dev','dfs_cac_state','dfs_radar_detected', \
                'interrupt_stats_dmaint','interrupt_stats_tx_bcn_succ','max_tx_power','noise_floor', \
                'num_clients','phy_type','radio_missing','secondary_channel','tx_power', \
                'utilization_all','utilization_non_wifi','utilization_rx_in_bss','utilization_rx_other_bss', \
                'utilization_tx','utilization_unknown_wifi']: 
        moreattr = moreattr.append(pd.DataFrame({each: data.head(length)[1].asDict()['radios'][i].asDict()[each]}, index = [i]),sort=True)

# %%
moreattr
# Out:
#   band  bandwidth  channel  dev dfs_cac_state dfs_radar_detected  \
# 0   24        NaN      NaN  NaN           NaN                NaN
# 0  NaN       20.0      NaN  NaN           NaN                NaN
# 0  NaN        NaN      1.0  NaN           NaN                NaN
# 0  NaN        NaN      NaN   r0           NaN                NaN
# 0  NaN        NaN      NaN  NaN          None                NaN
# 0  NaN        NaN      NaN  NaN           NaN               None
# 0  NaN        NaN      NaN  NaN           NaN                NaN
# 0  NaN        NaN      NaN  NaN           NaN                NaN
# 0  NaN        NaN      NaN  NaN           NaN                NaN
# 0  NaN        NaN      NaN  NaN           NaN                NaN
# 0  NaN        NaN      NaN  NaN           NaN                NaN
# 0  NaN        NaN      NaN  NaN           NaN                NaN
# 0  NaN        NaN      NaN  NaN           NaN                NaN
# ...

# %%
data.head(length)[1].asDict()['radios'][1].asDict()
# Out:
# {'ampdu_rx': Row(holes=None, stuck=None, rx_add_ba_req=None, tx_add_ba_resp=None, rx_bar=43, tx_ba=None, rx_unexpect=None, tx_del_ba=None, rx_del_ba=None),
#  'ampdu_tx': Row(fifo_full=None, drop=None, stuck=None, orphan=None, stuck_ps=None, r0hole=None, rnhole=None, rlag=None, tx_add_ba_req=2, rx_add_ba_resp=None, lost=None, tx_bar=None, rx_ba=None, no_ba=None, rx_unexpect=2, tx_del_ba=None, rx_del_ba=None, block_data_fifo=None, orphan_bad_ini=None, drop_no_buf=None, drop_err=None, orphan_bad_ini_free=None),
#  'band': u'5',
#  'bandwidth': 80,
#  'channel': 36,
# ...

# %%
data.head(length)[1].asDict()['radios'][0].asDict().keys()
# Out:
# ['interrupt_stats_dmaint',
#  'interrupt_stats_tx_bcn_succ',
#  'phy_type',
#  'bandwidth',
#  'utilization_all',
#  'ampdu_tx',
#  'dfs_radar_detected',
#  'noise_floor',
#  'utilization_rx_other_bss',
#  'max_tx_power',
#  'utilization_non_wifi',
#  'channel',
#  'radio_missing',
#  'band',
#  'pq',
#  'utilization_unknown_wifi',
#  'utilization_tx',
#  'num_clients',
#  'secondary_channel',
#  'probe_counter',
#  'ampdu_rx',
#  'counter',
#  'utilization_rx_in_bss',
#  'dev',
#  'pkt_pend',
#  'dfs_cac_state',
#  'per_antenna_rssi',
#  'non_aggr_regulate',
#  'tx_power']
